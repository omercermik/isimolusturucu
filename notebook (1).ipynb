# %%
import random
 
def kullanıcıAdı():
    isim = ["Ömer","Mübin","Esat","Serhat","Murat", "Yağız", "Mert", "Veli", "Erkan", "Bahadır", "Sena"]
    soyisim = ["Çermik", "Akkaşoğlu", "Atmaca", "Yaman", "Ataseven", "Yıldırım", "Bayraktar"]
    return "{} {}".format(random.choice(isim), random.choice(soyisim))
 
for i in range(1):
    print(kullanıcıAdı())
# Out:
# Murat Çermik
